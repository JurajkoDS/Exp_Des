# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('data/dominik/wandb_export_2025-01-27T22_23_09.875+01_00.csv')
pd.set_option("display.max_columns", None)

# %%
data.head(20)
# Out:
#                      Name     State Notes  User  Tags  \
# 0       fallen-thunder-94   crashed     -   NaN   NaN
# 1        easy-mountain-93  finished     -   NaN   NaN
# 2   efficient-aardvark-92  finished     -   NaN   NaN
# 3      dauntless-music-91  finished     -   NaN   NaN
# 4         earthy-plant-90  finished     -   NaN   NaN
# 5            deep-hill-89  finished     -   NaN   NaN
# 6      glorious-vortex-88  finished     -   NaN   NaN
# 7         tough-vortex-87  finished     -   NaN   NaN
# 8         swift-energy-86  finished     -   NaN   NaN
# 9           astral-bee-85  finished     -   NaN   NaN
# 10          jolly-hill-84  finished     -   NaN   NaN
# 11      fallen-terrain-83  finished     -   NaN   NaN
# 12      fragrant-night-82  finished     -   NaN   NaN
# 13         laced-water-81  finished     -   NaN   NaN
# 14         amber-night-80  finished     -   NaN   NaN
# 15       polished-wave-79  finished     -   NaN   NaN
# 16         vocal-smoke-78  finished     -   NaN   NaN
# 17         atomic-snow-77  finished     -   NaN   NaN
# 18          olive-pine-76  finished     -   NaN   NaN
# 19          lively-sun-75  finished     -   NaN   NaN
#
#                      Created  Runtime  Sweep                _hash  \
# 0   2025-01-14T07:56:37.000Z        1    NaN  1868926016067040500
# 1   2025-01-14T07:55:57.000Z       39    NaN  1179291037083628000
# 2   2025-01-14T07:55:18.000Z       38    NaN   315359558536605060
# 3   2025-01-14T07:54:41.000Z       35    NaN   821207727878663600
# 4   2025-01-14T07:54:06.000Z       34    NaN  1664157926746306300
# 5   2025-01-14T07:53:29.000Z       35    NaN   453592704829253400
# 6   2025-01-14T07:52:58.000Z       29    NaN   934843195360484100
# 7   2025-01-14T07:52:24.000Z       32    NaN  1686034882142333200
# 8   2025-01-14T07:51:51.000Z       31    NaN    72214697146297100
# 9   2025-01-14T07:51:18.000Z       31    NaN  2221331180595109600
# 10  2025-01-14T07:50:44.000Z       33    NaN  1189607494227435000
# 11  2025-01-14T07:50:10.000Z       32    NaN    68162393271441160
# 12  2025-01-14T07:49:32.000Z       36    NaN  1737416493581043700
# 13  2025-01-14T07:48:56.000Z       34    NaN  2081267029413055700
# 14  2025-01-14T07:48:19.000Z       35    NaN  1899656654282543900
# 15  2025-01-14T07:47:49.000Z       29    NaN  1455423004949931300
# 16  2025-01-14T07:47:14.000Z       33    NaN  1228785469200980000
# 17  2025-01-14T07:46:40.000Z       33    NaN   995789612313976400
# 18  2025-01-14T07:46:00.000Z       39    NaN  1283838753061316400
# 19  2025-01-14T07:45:33.000Z       25    NaN  1885939677042509800
#
#                            data_path  dislike_threshold end_sep  \
# 0   /root/.local/share/gpt-rec/ml-1m                2.5       ,
# 1   /root/.local/share/gpt-rec/ml-1m                2.5       ,
# 2   /root/.local/share/gpt-rec/ml-1m                2.5       ,
# 3   /root/.local/share/gpt-rec/ml-1m                2.5       ,
# 4   /root/.local/share/gpt-rec/ml-1m                2.5       ,
# 5   /root/.local/share/gpt-rec/ml-1m                2.5       ,
# 6   /root/.local/share/gpt-rec/ml-1m                2.5       ,
# 7   /root/.local/share/gpt-rec/ml-1m                2.5       ,
# 8   /root/.local/share/gpt-rec/ml-1m                2.5       ,
# 9   /root/.local/share/gpt-rec/ml-1m                2.5       ,
# 10  /root/.local/share/gpt-rec/ml-1m                2.5       ,
# 11  /root/.local/share/gpt-rec/ml-1m                2.5       ,
# 12  /root/.local/share/gpt-rec/ml-1m                2.5       ,
# 13  /root/.local/share/gpt-rec/ml-1m                2.5       ,
# 14  /root/.local/share/gpt-rec/ml-1m                2.5       ,
# 15  /root/.local/share/gpt-rec/ml-1m                2.5       ,
# 16  /root/.local/share/gpt-rec/ml-1m                2.5       ,
# 17  /root/.local/share/gpt-rec/ml-1m                2.5       ,
# 18  /root/.local/share/gpt-rec/ml-1m                2.5       ,
# 19  /root/.local/share/gpt-rec/ml-1m                2.5       ,
#
#     like_threshold  min_neg_ratings  min_pos_ratings model_type  nb_neg  \
# 0                4                5               21       gpt2       4
# 1                4                5               21       gpt2       4
# 2                4                5               21       gpt2       4
# 3                4                5               21       gpt2       4
# 4                4                5               21       gpt2       4
# 5                4                5               21       gpt2       4
# 6                4                5               21       gpt2       4
# 7                4                5               21       gpt2       4
# 8                4                5               21       gpt2       4
# 9                4                5               21       gpt2       4
# 10               4                5               21       gpt2       4
# 11               4                5               21       gpt2       4
# 12               4                5               21       gpt2       4
# 13               4                5               21       gpt2       4
# 14               4                5               21       gpt2       4
# 15               4                5               21       gpt2       4
# 16               4                5               21       gpt2       4
# 17               4                5               21       gpt2       4
# 18               4                5               21       gpt2       4
# 19               4                5               21       gpt2       4
#
#     nb_pos  nb_test_users  offset  prompt_id  \
# 0        5             50     100          3
# 1        5             50     100          0
# 2        5             50      50          3
# 3        5             50      50          0
# 4        5             50       0          3
# 5        5             50       0          0
# 6        3             50     150          3
# 7        3             50     150          0
# 8        3             50     100          3
# 9        3             50     100          0
# 10       3             50      50          3
# 11       3             50      50          0
# 12       3             50       0          3
# 13       3             50       0          0
# 14       2             50     150          3
# 15       2             50     150          0
# 16       2             50     100          3
# 17       2             50     100          0
# 18       2             50      50          3
# 19       2             50      50          0
#
#                                               prompts sep  users_seed xp_name  \
# 0   ('[M]', 'Movies like [M]', 'Movies similar to ...   ,           0  nb_pos
# 1   ('[M]', 'Movies like [M]', 'Movies similar to ...   ,           0  nb_pos
# 2   ('[M]', 'Movies like [M]', 'Movies similar to ...   ,           0  nb_pos
# 3   ('[M]', 'Movies like [M]', 'Movies similar to ...   ,           0  nb_pos
# 4   ('[M]', 'Movies like [M]', 'Movies similar to ...   ,           0  nb_pos
# 5   ('[M]', 'Movies like [M]', 'Movies similar to ...   ,           0  nb_pos
# 6   ('[M]', 'Movies like [M]', 'Movies similar to ...   ,           0  nb_pos
# 7   ('[M]', 'Movies like [M]', 'Movies similar to ...   ,           0  nb_pos
# 8   ('[M]', 'Movies like [M]', 'Movies similar to ...   ,           0  nb_pos
# 9   ('[M]', 'Movies like [M]', 'Movies similar to ...   ,           0  nb_pos
# 10  ('[M]', 'Movies like [M]', 'Movies similar to ...   ,           0  nb_pos
# 11  ('[M]', 'Movies like [M]', 'Movies similar to ...   ,           0  nb_pos
# 12  ('[M]', 'Movies like [M]', 'Movies similar to ...   ,           0  nb_pos
# 13  ('[M]', 'Movies like [M]', 'Movies similar to ...   ,           0  nb_pos
# 14  ('[M]', 'Movies like [M]', 'Movies similar to ...   ,           0  nb_pos
# 15  ('[M]', 'Movies like [M]', 'Movies similar to ...   ,           0  nb_pos
# 16  ('[M]', 'Movies like [M]', 'Movies similar to ...   ,           0  nb_pos
# 17  ('[M]', 'Movies like [M]', 'Movies similar to ...   ,           0  nb_pos
# 18  ('[M]', 'Movies like [M]', 'Movies similar to ...   ,           0  nb_pos
# 19  ('[M]', 'Movies like [M]', 'Movies similar to ...   ,           0  nb_pos
#
#     ndcg_1  ndcg_1_std    ndcg_2  ndcg_2_std    ndcg_3  ndcg_3_std    ndcg_4  \
# 0      NaN         NaN       NaN         NaN       NaN         NaN       NaN
# 1     0.32    0.466476  0.458805    0.443931  0.568805    0.372877  0.637713
# 2     0.34    0.473709  0.504042    0.435248  0.594042    0.368257  0.619882
# 3     0.34    0.473709  0.504042    0.435248  0.584042    0.377351  0.652950
# 4     0.32    0.466476  0.433567    0.451301  0.533567    0.396180  0.593862
# 5     0.24    0.427083  0.404042    0.424558  0.504042    0.373418  0.555723
# 6     0.34    0.473709  0.516660    0.429561  0.576660    0.385906  0.619728
# 7     0.38    0.485386  0.468330    0.465185  0.568330    0.403399  0.637238
# 8     0.24    0.427083  0.378805    0.429049  0.478805    0.385126  0.547713
# 9     0.42    0.493559  0.520949    0.460765  0.590949    0.411669  0.642630
# 10    0.40    0.489898  0.538805    0.444146  0.608805    0.389786  0.677713
# 11    0.40    0.489898  0.475712    0.470603  0.555712    0.423029  0.641847
# 12    0.32    0.466476  0.458805    0.443931  0.538805    0.396567  0.599099
# 13    0.28    0.448999  0.431423    0.435214  0.541423    0.370673  0.610331
# 14    0.36    0.480000  0.511423    0.440436  0.581423    0.390493  0.658945
# 15    0.40    0.489898  0.500949    0.461240  0.620949    0.371637  0.672630
# 16    0.22    0.414246  0.409279    0.414623  0.509279    0.360634  0.569574
# 17    0.40    0.489898  0.526186    0.450270  0.616186    0.380696  0.642027
# 18    0.46    0.498397  0.573567    0.450193  0.633567    0.400307  0.719703
# 19    0.36    0.480000  0.549279    0.421562  0.629279    0.351326  0.672347
#
#     ndcg_4_std    ndcg_5  ndcg_5_std     pop_1  pop_1_std  precision_1  \
# 0          NaN       NaN         NaN       NaN        NaN          NaN
# 1     0.292533  0.668661    0.238994  4.934531   5.203659         0.32
# 2     0.339667  0.681779    0.242385  4.728799   4.584142         0.34
# 3     0.294673  0.683898    0.239649  5.224734   5.527623         0.34
# 4     0.339040  0.655759    0.248085  6.067134   5.511233         0.32
# 5     0.327000  0.625356    0.227209  4.566690   4.558128         0.24
# 6     0.340508  0.681624    0.243601  4.658560   4.488739         0.34
# 7     0.330658  0.683661    0.256854  4.303565   3.464749         0.38
# 8     0.327511  0.617346    0.230379  4.321754   3.739992         0.24
# 9     0.357738  0.704526    0.261795  4.013054   3.575718         0.42
# 10    0.304891  0.708661    0.249048  5.855185   5.552313         0.40
# 11    0.336003  0.688269    0.262886  4.560421   5.302063         0.40
# 12    0.338561  0.660996    0.246116  4.158515   4.707970         0.32
# 13    0.296159  0.649017    0.232287  3.585097   3.577458         0.28
# 14    0.299526  0.689893    0.244835  6.586859   6.464567         0.36
# 15    0.305808  0.703578    0.250798  5.184348   6.050187         0.40
# 16    0.301621  0.623733    0.217481  4.901749   4.711699         0.22
# 17    0.351490  0.703923    0.253339  4.984165   5.030232         0.40
# 18    0.284214  0.735177    0.253477  5.279866   5.072834         0.46
# 19    0.293121  0.703295    0.235199  4.806231   5.435213         0.36
#
#     precision_1_std  precision_2  precision_2_std  precision_3  \
# 0               NaN          NaN              NaN          NaN
# 1          0.466476         0.27         0.249199     0.253333
# 2          0.473709         0.30         0.244949     0.260000
# 3          0.473709         0.30         0.244949     0.253333
# 4          0.466476         0.25         0.250000     0.233333
# 5          0.427083         0.25         0.250000     0.233333
# 6          0.473709         0.31         0.242693     0.246667
# 7          0.485386         0.26         0.249800     0.240000
# 8          0.427083         0.23         0.249199     0.220000
# 9          0.493559         0.29         0.246779     0.240000
# 10         0.489898         0.31         0.242693     0.253333
# 11         0.489898         0.26         0.249800     0.226667
# 12         0.466476         0.27         0.249199     0.233333
# 13         0.448999         0.26         0.249800     0.246667
# 14         0.480000         0.30         0.244949     0.246667
# 15         0.489898         0.28         0.248193     0.266667
# 16         0.414246         0.26         0.249800     0.240000
# 17         0.489898         0.30         0.244949     0.260000
# 18         0.498397         0.32         0.240000     0.253333
# 19         0.480000         0.33         0.236854     0.273333
#
#     precision_3_std  precision_4  precision_4_std  precision_5  \
# 0               NaN          NaN              NaN          NaN
# 1          0.142361        0.230         0.067823          0.2
# 2          0.138082        0.210         0.091652          0.2
# 3          0.142361        0.230         0.067823          0.2
# 4          0.152753        0.210         0.091652          0.2
# 5          0.152753        0.205         0.096047          0.2
# 6          0.146211        0.210         0.091652          0.2
# 7          0.149666        0.220         0.081240          0.2
# 8          0.157903        0.205         0.096047          0.2
# 9          0.149666        0.210         0.091652          0.2
# 10         0.142361        0.230         0.067823          0.2
# 11         0.155492        0.220         0.081240          0.2
# 12         0.152753        0.210         0.091652          0.2
# 13         0.146211        0.225         0.075000          0.2
# 14         0.146211        0.230         0.067823          0.2
# 15         0.133333        0.230         0.067823          0.2
# 16         0.149666        0.215         0.086747          0.2
# 17         0.138082        0.210         0.091652          0.2
# 18         0.142361        0.240         0.048990          0.2
# 19         0.128062        0.230         0.067823          0.2
#
#     precision_5_std  recall_1  recall_1_std  recall_2  recall_2_std  recall_3  \
# 0               NaN       NaN           NaN       NaN           NaN       NaN
# 1      5.551115e-17      0.32      0.466476      0.54      0.498397      0.76
# 2      5.551115e-17      0.34      0.473709      0.60      0.489898      0.78
# 3      5.551115e-17      0.34      0.473709      0.60      0.489898      0.76
# 4      5.551115e-17      0.32      0.466476      0.50      0.500000      0.70
# 5      5.551115e-17      0.24      0.427083      0.50      0.500000      0.70
# 6      5.551115e-17      0.34      0.473709      0.62      0.485386      0.74
# 7      5.551115e-17      0.38      0.485386      0.52      0.499600      0.72
# 8      5.551115e-17      0.24      0.427083      0.46      0.498397      0.66
# 9      5.551115e-17      0.42      0.493559      0.58      0.493559      0.72
# 10     5.551115e-17      0.40      0.489898      0.62      0.485386      0.76
# 11     5.551115e-17      0.40      0.489898      0.52      0.499600      0.68
# 12     5.551115e-17      0.32      0.466476      0.54      0.498397      0.70
# 13     5.551115e-17      0.28      0.448999      0.52      0.499600      0.74
# 14     5.551115e-17      0.36      0.480000      0.60      0.489898      0.74
# 15     5.551115e-17      0.40      0.489898      0.56      0.496387      0.80
# 16     5.551115e-17      0.22      0.414246      0.52      0.499600      0.72
# 17     5.551115e-17      0.40      0.489898      0.60      0.489898      0.78
# 18     5.551115e-17      0.46      0.498397      0.64      0.480000      0.76
# 19     5.551115e-17      0.36      0.480000      0.66      0.473709      0.82
#
#     recall_3_std  recall_4  recall_4_std  recall_5  recall_5_std
# 0            NaN       NaN           NaN       NaN           NaN
# 1       0.427083      0.92      0.271293       1.0           0.0
# 2       0.414246      0.84      0.366606       1.0           0.0
# 3       0.427083      0.92      0.271293       1.0           0.0
# 4       0.458258      0.84      0.366606       1.0           0.0
# 5       0.458258      0.82      0.384187       1.0           0.0
# 6       0.438634      0.84      0.366606       1.0           0.0
# 7       0.448999      0.88      0.324962       1.0           0.0
# 8       0.473709      0.82      0.384187       1.0           0.0
# 9       0.448999      0.84      0.366606       1.0           0.0
# 10      0.427083      0.92      0.271293       1.0           0.0
# 11      0.466476      0.88      0.324962       1.0           0.0
# 12      0.458258      0.84      0.366606       1.0           0.0
# 13      0.438634      0.90      0.300000       1.0           0.0
# 14      0.438634      0.92      0.271293       1.0           0.0
# 15      0.400000      0.92      0.271293       1.0           0.0
# 16      0.448999      0.86      0.346987       1.0           0.0
# 17      0.414246      0.84      0.366606       1.0           0.0
# 18      0.427083      0.96      0.195959       1.0           0.0
# 19      0.384187      0.92      0.271293       1.0           0.0

# %%
data_filtered = data[['Name', 'Runtime', 'model_type', 'nb_pos', 'ndcg_1', 'ndcg_1_std', 'pop_1', 'pop_1_std', 'precision_1', 'precision_1_std', 'prompts','nb_test_users', 'offset']]
data_filtered = data_filtered[data_filtered['model_type'] == 'gpt2']
data_filtered
# Out:
#                      Name  Runtime model_type  nb_pos  ndcg_1  ndcg_1_std  \
# 0       fallen-thunder-94        1       gpt2       5     NaN         NaN
# 1        easy-mountain-93       39       gpt2       5    0.32    0.466476
# 2   efficient-aardvark-92       38       gpt2       5    0.34    0.473709
# 3      dauntless-music-91       35       gpt2       5    0.34    0.473709
# 4         earthy-plant-90       34       gpt2       5    0.32    0.466476
# ..                    ...      ...        ...     ...     ...         ...
# 89          copper-bird-5       18       gpt2       1    0.24    0.427083
# 90           rosy-voice-4       21       gpt2       1    0.44    0.496387
# 91     gentle-firebrand-3       18       gpt2       1    0.30    0.458258
# 92            neat-tree-2       20       gpt2       1    0.32    0.466476
# 93        true-capybara-1       84       gpt2       1    0.28    0.448999
#
#        pop_1  pop_1_std  precision_1  precision_1_std  \
# 0        NaN        NaN          NaN              NaN
# 1   4.934531   5.203659         0.32         0.466476
# 2   4.728799   4.584142         0.34         0.473709
# 3   5.224734   5.527623         0.34         0.473709
# 4   6.067134   5.511233         0.32         0.466476
# ..       ...        ...          ...              ...
# 89  3.809377   3.674253         0.24         0.427083
# 90  5.227303   4.841235         0.44         0.496387
# 91  3.945538   4.716521         0.30         0.458258
# 92  5.941506   6.510474         0.32         0.466476
# 93  3.986746   5.090405         0.28         0.448999
#
#                                               prompts  nb_test_users  offset
# 0   ('[M]', 'Movies like [M]', 'Movies similar to ...             50     100
# 1   ('[M]', 'Movies like [M]', 'Movies similar to ...             50     100
# 2   ('[M]', 'Movies like [M]', 'Movies similar to ...             50      50
# 3   ('[M]', 'Movies like [M]', 'Movies similar to ...             50      50
# 4   ('[M]', 'Movies like [M]', 'Movies similar to ...             50       0
# ..                                                ...            ...     ...
# 89  ('[M]', 'Movies like [M]', 'Movies similar to ...             50     100
# 90  ('[M]', 'Movies like [M]', 'Movies similar to ...             50      50
# 91  ('[M]', 'Movies like [M]', 'Movies similar to ...             50      50
# 92  ('[M]', 'Movies like [M]', 'Movies similar to ...             50       0
# 93  ('[M]', 'Movies like [M]', 'Movies similar to ...             50       0
#
# [94 rows x 13 columns]

# %%
data_filtered['offset'].unique()
# Out:
# array([100,  50,   0, 150])

# %%
data_filtered['prompts'].unique()
# Out:
# array(["('[M]', 'Movies like [M]', 'Movies similar to [M]', 'Movies like: [M]', 'Movies similar to: [M]', 'If you liked [M] you will also like')"],
#       dtype=object)

# %%
data_filtered['MAP@1'] = data_filtered['precision_1'] / data_filtered.shape[0] * 100
data_filtered
# Out:
#                      Name  Runtime model_type  nb_pos  ndcg_1  ndcg_1_std  \
# 0       fallen-thunder-94        1       gpt2       5     NaN         NaN
# 1        easy-mountain-93       39       gpt2       5    0.32    0.466476
# 2   efficient-aardvark-92       38       gpt2       5    0.34    0.473709
# 3      dauntless-music-91       35       gpt2       5    0.34    0.473709
# 4         earthy-plant-90       34       gpt2       5    0.32    0.466476
# ..                    ...      ...        ...     ...     ...         ...
# 89          copper-bird-5       18       gpt2       1    0.24    0.427083
# 90           rosy-voice-4       21       gpt2       1    0.44    0.496387
# 91     gentle-firebrand-3       18       gpt2       1    0.30    0.458258
# 92            neat-tree-2       20       gpt2       1    0.32    0.466476
# 93        true-capybara-1       84       gpt2       1    0.28    0.448999
#
#        pop_1  pop_1_std  precision_1  precision_1_std  \
# 0        NaN        NaN          NaN              NaN
# 1   4.934531   5.203659         0.32         0.466476
# 2   4.728799   4.584142         0.34         0.473709
# 3   5.224734   5.527623         0.34         0.473709
# 4   6.067134   5.511233         0.32         0.466476
# ..       ...        ...          ...              ...
# 89  3.809377   3.674253         0.24         0.427083
# 90  5.227303   4.841235         0.44         0.496387
# 91  3.945538   4.716521         0.30         0.458258
# 92  5.941506   6.510474         0.32         0.466476
# 93  3.986746   5.090405         0.28         0.448999
#
#                                               prompts  nb_test_users  offset  \
# 0   ('[M]', 'Movies like [M]', 'Movies similar to ...             50     100
# 1   ('[M]', 'Movies like [M]', 'Movies similar to ...             50     100
# 2   ('[M]', 'Movies like [M]', 'Movies similar to ...             50      50
# 3   ('[M]', 'Movies like [M]', 'Movies similar to ...             50      50
# 4   ('[M]', 'Movies like [M]', 'Movies similar to ...             50       0
# ..                                                ...            ...     ...
# 89  ('[M]', 'Movies like [M]', 'Movies similar to ...             50     100
# 90  ('[M]', 'Movies like [M]', 'Movies similar to ...             50      50
# 91  ('[M]', 'Movies like [M]', 'Movies similar to ...             50      50
# 92  ('[M]', 'Movies like [M]', 'Movies similar to ...             50       0
# 93  ('[M]', 'Movies like [M]', 'Movies similar to ...             50       0
#
#        MAP@1
# 0        NaN
# 1   0.340426
# 2   0.361702
# 3   0.361702
# 4   0.340426
# ..       ...
# 89  0.255319
# 90  0.468085
# 91  0.319149
# 92  0.340426
# 93  0.297872
#
# [94 rows x 14 columns]

# %%
data_filtered.describe()
# Out:
#          Runtime     nb_pos     ndcg_1  ndcg_1_std      pop_1  pop_1_std  \
# count  94.000000  94.000000  93.000000   93.000000  93.000000  93.000000
# mean   29.882979   6.191489   0.359140    0.474071   5.248593   5.210319
# std    11.218127   5.831462   0.069574    0.022904   0.856550   0.809792
# min     1.000000   1.000000   0.200000    0.400000   3.384400   3.428856
# 25%    21.250000   2.000000   0.320000    0.466476   4.696017   4.716521
# 50%    26.500000   3.000000   0.360000    0.480000   5.269333   5.269850
# 75%    35.000000   9.250000   0.400000    0.489898   5.855853   5.775755
# max    84.000000  20.000000   0.500000    0.500000   7.364262   7.202305
#
#        precision_1  precision_1_std  nb_test_users      offset      MAP@1
# count    93.000000        93.000000           94.0   94.000000  93.000000
# mean      0.359355         0.474239           50.0   73.404255   0.382292
# std       0.069623         0.022953            0.0   55.697980   0.074067
# min       0.200000         0.400000           50.0    0.000000   0.212766
# 25%       0.320000         0.466476           50.0   12.500000   0.340426
# 50%       0.360000         0.480000           50.0   50.000000   0.382979
# 75%       0.400000         0.489898           50.0  100.000000   0.425532
# max       0.500000         0.500000           50.0  150.000000   0.531915

# %%
sns.lineplot(data=data_filtered, x="nb_pos", y="MAP@1")
plt.xlabel("#Movies per user")
plt.grid(True)
